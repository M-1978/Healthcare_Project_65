# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("healthcare_dataset.csv")

# %%
#understanding the data

# %%
data.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
data.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
data.shape
# Out:
# (55500, 15)

# %%
data.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='str')

# %%
data.nunique()
# Out:
# Name                  49992
# Age                      77
# Gender                    2
# Blood Type                8
# Medical Condition         6
# Date of Admission      1827
# Doctor                40341
# Hospital              39876
# Insurance Provider        5
# Billing Amount        50000
# Room Number             400
# Admission Type            3
# Discharge Date         1856
# Medication                5
# Test Results              3
# dtype: int64

# %%
data['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
#relationship analysis

# %%
correlation = data.corr(numeric_only=True)
print(correlation)
# Out:
#                      Age  Billing Amount  Room Number
# Age             1.000000       -0.003832    -0.000720
# Billing Amount -0.003832        1.000000    -0.002943
# Room Number    -0.000720       -0.002943     1.000000

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(data['Age'], bins=20)
plt.title("Age Distribution")
plt.show()

# %%
sns.countplot(x='Gender', data=data)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(y='Medical Condition', data=data)
plt.title("Medical Conditions")
plt.show()

# %%
sns.histplot(data['Billing Amount'], bins=20)
plt.title("Billing Amount Distribution")
plt.show()

# %%
print("Insights:")
print("- The dataset contains patients of various age groups.")
print("- Common medical conditions include Diabetes, Obesity, etc.")
print("- Billing amounts vary significantly among patients.")
print("- There is no strong correlation between numerical variables.")
# Out:
# Insights:
# - The dataset contains patients of various age groups.
# - Common medical conditions include Diabetes, Obesity, etc.
# - Billing amounts vary significantly among patients.
# - There is no strong correlation between numerical variables.

# %%
print("Decision-Making Support:")
print("- Hospitals can allocate resources based on common diseases.")
print("- Billing analysis helps in financial planning.")
print("- Patient trends help improve healthcare services.")
# Out:
# Decision-Making Support:
# - Hospitals can allocate resources based on common diseases.
# - Billing analysis helps in financial planning.
# - Patient trends help improve healthcare services.

# %%
print("Conclusion:")
print("This project analyzed healthcare data using Python.")
print("Data cleaning, EDA, visualization, and correlation analysis were performed.")
print("The results show patterns in patient data and highlight independence of variables.")
print("This analysis helps improve healthcare decision-making and resource allocation.")
# Out:
# Conclusion:
# This project analyzed healthcare data using Python.
# Data cleaning, EDA, visualization, and correlation analysis were performed.
# The results show patterns in patient data and highlight independence of variables.
# This analysis helps improve healthcare decision-making and resource allocation.
